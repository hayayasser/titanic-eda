# %% [markdown]
# # Kaggle Titanics Dataset EDA

# %%
# Haya Yasser
# Exploratory analysis of Titanic dataset using Python and Pandas
# Oct 2025

# %% [markdown]
# ## Imports

# %%
import os
import shutil
import pandas as pd

# %% [markdown]
# ## Downloading & Reading Titanics Dataset via Kaggle API

# %%
# !pip install kaggle

# %%
# Creating the hidden .kaggle folder in home directory
os.makedirs(os.path.expanduser("~/.kaggle"), exist_ok=True)

# %%
# Managing permissions
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Downloading dataset
# !kaggle competitions download -c titanic
# Out:
# ...
#   0%|                                               | 0.00/34.1k [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 34.1k/34.1k [00:00<00:00, 28.4MB/s]

# %%
# Unzipping dataset folder
# !unzip titanic.zip -d .
# Out:
# Archive:  titanic.zip
#   inflating: ./gender_submission.csv
#   inflating: ./test.csv
#   inflating: ./train.csv

# %%
# Reading the train.csv file into a DataFrame
df = pd.read_csv("train.csv", index_col=0)

# %% [markdown]
# ## Overview of Dataset

# %%
# Displaying the first 5 records
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## Some Basic Analysis

# %%
# Calculating the number of missing values per column
print("NaN counts per column: ")
df.isna().sum()
# Out:
# NaN counts per column:
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# family_size      0
# dtype: int64

# %%
# Extracting the number of passengers older than 50
df.loc[df.Age > 50]
# Out:
#              Survived  Pclass  \
# PassengerId
# 7                   0       1
# 12                  1       1
# 16                  1       2
# 34                  0       2
# 55                  0       1
# ...               ...     ...
# 821                 1       1
# 830                 1       1
# 852                 0       3
# 858                 1       1
# 880                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 34                                       Wheadon, Mr. Edward H    male  66.0
# 55                              Ostby, Mr. Engelhart Cornelius    male  65.0
# ...                                                        ...     ...   ...
# ...

# %%
# Creating a new column for each passenger's family size (SibSp + Parch + 1)
# SibSp -> no. of spouses/siblings aboard the Titanic
# Parch -> no. of parents / children aboard the Titanic

df['family_size'] = df.SibSp + df.Parch + 1
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...
